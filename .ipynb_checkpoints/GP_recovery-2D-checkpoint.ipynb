# %%
import numpy as np
import matplotlib.pyplot as plt
from PyAstronomy import pyasl
from datetime import datetime
import celerite
from celerite import terms
from scipy.optimize import minimize
from scipy.signal import find_peaks
from astropy.timeseries import LombScargle
from datetime import timedelta, date
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

from NEID_solar_functions import *
from GP_kernels import *

# %%
import jax
import jax.numpy as jnp
from tinygp import kernels, GaussianProcess
import tinygp

jax.config.update("jax_enable_x64", True)

uHz_conv = 1e-6 * 60

def gaussian_2(x, amp, mu, sig):
    return amp * jnp.exp(-jnp.power(x - mu, 2.) / (2 * jnp.power(sig, 2.))) 

amp0, mu0, sig0 = np.array([ 5.46875972e-03,  3.08082489e+03, 3.05370933e+02])    
amp0 *= 6e1
nu_max0 = mu0
delta_nu0 = 135
epsilon0 = 0
Q0 = 4e2
N0 = 7 # 25*135/2=1620

nu_max=nu_max0
delta_nu=delta_nu0
epsilon=epsilon0
Q=Q0
amp=amp0
sig=sig0
N=N0    
    
kernel = 0  
for i in range(N):
    omega = 2*np.pi*(nu_max + (-(N-1)/2+i)*delta_nu/2 + epsilon)*uHz_conv
    sigma = gaussian_2(nu_max + (-(N-1)/2+i)*delta_nu/2 + epsilon, amp, nu_max, sig) 
    kernel += tinygp.kernels.quasisep.SHO(omega, Q, sigma)
    print(sigma)
# Out:
# 2022-11-08 15:18:34.134000: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2022-11-08 15:18:34.169154: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2022-11-08 15:18:34.170804: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2022-11-08 15:18:34.563722: W external/org_tensorflow/tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /storage/icds/RISE/sw8/julia-1.8.1/julia-1.8.1/lib:/storage/icds/RISE/sw8/anaconda/anaconda3/lib
# 2022-11-08 15:18:34.563739: W external/org_tensorflow/tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# WARNING:jax._src.lib.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 0.26336135786308595
# 0.29757809812482694
# 0.3202066230161938
# 0.3281255832
# 0.3202066230161938
# 0.29757809812482694
# 0.26336135786308595

# %% [markdown]
# ### Scenario 1 - 700 min, 50 repetitions

# %%
Nr = 50
t = np.linspace(0, 700, 701)
gp = GaussianProcess(kernel, t)
y = gp.sample(jax.random.PRNGKey(4), shape=(Nr,))
t.shape, y.shape
# Out:
# ((701,), (50, 701))

# %%
plt.rcParams.update({'font.size': 16})
T_env = max(t)/3

for i in range(3):
    fig = plt.figure(figsize=(16, 2))
    if i==0:
        plt.title('Simulated p-mode oscillation')
    idx_t = ((t>=i*T_env) & (t<(i+1)*T_env))
    plt.plot(t[idx_t], y.T[idx_t], '-', alpha=1)
    plt.ylabel('RV [m/s]')
    plt.xlim([i*T_env, (i+1)*T_env])
    plt.ylim([-3.5, 3.5])
    plt.grid(True)
    plt.show()

# %%
ACF = np.zeros((Nr, len(t)))

for i in range(Nr):
    ACF[i,:] = sm.tsa.acovf(y[i,:], fft=True)/(1-t/max(t*1.001))

fig = plt.figure(figsize=(16, 6))
plt.plot(t, ACF.T, alpha=0.1)
plt.plot(t, np.mean(ACF, axis=0), lw=2, color='r', label='mean')
plt.title('ACF for simulated data')
plt.xlim([0,600])
plt.ylim([-1,1.0])
plt.xlabel(r'$\Delta t$ [minutes]')
plt.ylabel(r'Covariance [m$^2$/s$^2$]')
plt.legend()
plt.show()

# %%
ACF2 = ACF

# %% [markdown]
# ### Scenario 2 - 35000 (50*700) min

# %%
Nr = 1
t = np.linspace(0, 35000, 35001)
gp = GaussianProcess(kernel, t)
y = gp.sample(jax.random.PRNGKey(4), shape=(Nr,))
t.shape, y.shape
# Out:
# ((35001,), (1, 35001))

# %%
plt.rcParams.update({'font.size': 16})
T_env = max(t)/3

for i in range(3):
    fig = plt.figure(figsize=(16, 2))
    if i==0:
        plt.title('Simulated p-mode oscillation')
    idx_t = ((t>=i*T_env) & (t<(i+1)*T_env))
    plt.plot(t[idx_t], y.T[idx_t], '-', alpha=1)
    plt.ylabel('RV [m/s]')
    plt.xlim([i*T_env, (i+1)*T_env])
    plt.ylim([-3.5, 3.5])
    plt.grid(True)
    plt.show()

# %%
ACF2.shape, ACF.shape
# Out:
# ((50, 701), (50, 701))

# %%
ACF = np.zeros((Nr, len(t)))

for i in range(Nr):
    ACF[i,:] = sm.tsa.acovf(y[i,:], fft=True)/(1-t/max(t*1.001))

fig = plt.figure(figsize=(16, 6))
plt.plot(t[t<=700], np.mean(ACF2, axis=0), lw=2, color='b', label='50*700')
plt.plot(t, np.mean(ACF, axis=0), lw=2, color='r', label='35,000')
plt.title('ACF for simulated data')
plt.xlim([0,600])
plt.ylim([-1,1.0])
plt.xlabel(r'$\Delta t$ [minutes]')
plt.ylabel(r'Covariance [m$^2$/s$^2$]')
plt.legend()
plt.show()

# %% [markdown]
# # One day of data

# %% [markdown]
# ## Test 1.1 - time domain

# %%
Nr = 1
t = np.linspace(0, 700, 701)
gp = GaussianProcess(kernel, t)
y = gp.sample(jax.random.PRNGKey(4), shape=(Nr,))
y = y[0,:]
t.shape, y.shape
# Out:
# ((701,), (701,))

# %%
def build_gp(theta, X):

    # We want most of our parameters to be positive so we take the `exp` here
    # Note that we're using `jnp` instead of `np`
    Q = jnp.exp(theta["log_Q"])
    nu_max = jnp.exp(theta["log_nu_max"])

    kernel = 0     
    for i in range(N):
        omega = 2*np.pi*(nu_max + (-(N-1)/2+i)*delta_nu/2 + epsilon)*uHz_conv
        sigma = gaussian_2(nu_max + (-(N-1)/2+i)*delta_nu/2 + epsilon, amp, nu_max, sig) 
        kernel += tinygp.kernels.quasisep.SHO(omega, Q, sigma)
            
    return GaussianProcess(kernel, X), kernel

def neg_log_likelihood(theta, X, y):
    gp, _ = build_gp(theta, X)
    return -gp.log_probability(y)


theta_init = {
    # "log_diag": np.log(0.5),
    "log_Q": np.log(1000),
    # "log_A": np.log(amp0),
    # "log_W": np.log(300),
    "log_nu_max": np.log(3000),
    # "log_delta_nu": np.log(135),
    # "epsilon": np.float64(0.0)
}


# `jax` can be used to differentiate functions, and also note that we're calling
# `jax.jit` for the best performance.
obj = jax.jit(jax.value_and_grad(neg_log_likelihood))

print(f"Initial negative log likelihood: {obj(theta_init, t, y)[0]}")
print(
    f"Gradient of the negative log likelihood, wrt the parameters:\n{obj(theta_init, t, y)[1]}"
)
# Out:
# Initial negative log likelihood: 16.12503045560993
# Gradient of the negative log likelihood, wrt the parameters:
# {'log_Q': DeviceArray(1420.0644429, dtype=float64), 'log_nu_max': DeviceArray(-46778.98407482, dtype=float64)}

# %%
w_init = jnp.zeros(len(theta_init))
lower_bounds = jnp.ones_like(w_init)* (-1)
upper_bounds = jnp.ones_like(w_init) * jnp.inf
bounds = (lower_bounds, upper_bounds)

import jaxopt
solver = jaxopt.ScipyBoundedMinimize(fun=neg_log_likelihood)
soln = solver.run(theta_init, bounds=bounds, X=t, y=y)
print(f"Final negative log likelihood: {soln.state.fun_val}")
# Out:
# Final negative log likelihood: -980.1453578867531

# %%
soln.params
# Out:
# {'log_Q': DeviceArray(5.73175745, dtype=float64),
#  'log_nu_max': DeviceArray(8.03297246, dtype=float64)}

# %%
for key, value in soln.params.items():
    print(key[4:], np.exp(value))
# Out:
# Q 308.5109840222349
# nu_max 3080.8858909403143

# %% [markdown]
# ## Test 1.2 - Covariance space

# %%
acf = sm.tsa.acovf(y, fft=True)/(1-t/max(t*1.001))
fig = plt.figure(figsize=(16, 6))
plt.plot(t, acf, lw=2, color='k')
plt.title('ACF for simulated data')
plt.xlim([0,600])
# plt.ylim([-1,1.0])
plt.xlabel(r'$\Delta t$ [minutes]')
plt.ylabel(r'Covariance [m$^2$/s$^2$]')
plt.show()

# %%
def gaussian_2(x, amp, mu, sig):
    return amp * np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.))) 

def kernel_function(Q):
    kernel = 0  
    for i in range(3):
        omega = 2*np.pi*(nu_max + (-(N-1)/2+i)*delta_nu/2 + epsilon)*uHz_conv
        sigma = gaussian_2(nu_max + (-(N-1)/2+i)*delta_nu/2 + epsilon, amp, nu_max, sig) 
        kernel += tinygp.kernels.quasisep.SHO(omega, Q, sigma)
    return kernel

dx = t[t<=600]
def diff(Q):
    kernel = kernel_function(Q)
    return (np.array(kernel(dx, dx[:1])).T-acf[t<=600]).flatten()

def objective_function(Q):
    return sum(diff(Q)**2)

# %%
for xx in np.linspace(1, 1000, 20):
    plt.plot(xx, objective_function(xx), 'ko')
    plt.xlabel('Q')
    plt.ylabel('loss')
plt.show()

# %%
for xx in np.linspace(180, 300, 20):
    plt.plot(xx, objective_function(xx), 'ko')
    plt.xlabel('Q')
    plt.ylabel('loss')
plt.show()

# %%
# res = minimize(objective_function, x0=np.array([400]))

# %% [markdown]
# # Multiple days of data combined

# %%
Nr = 1
t = np.linspace(0, 35000, 35001)
gp = GaussianProcess(kernel, t)
y = gp.sample(jax.random.PRNGKey(4), shape=(Nr,))
t.shape, y.shape
# Out:
# ((35001,), (1, 35001))

# %% [markdown]
# ## Test 2.1 - Covariance space

# %%
fig = plt.figure(figsize=(16, 6))
plt.plot(t, np.mean(ACF, axis=0), lw=2, color='r', label='mean')
plt.title('ACF for simulated data')
plt.xlim([0,600])
plt.ylim([-1,1.0])
plt.xlabel(r'$\Delta t$ [minutes]')
plt.ylabel(r'Covariance [m$^2$/s$^2$]')
plt.legend()
plt.show()

# %%
acf = ACF[0, :]

for xx in np.linspace(1, 1000, 20):
    plt.plot(xx, objective_function(xx), 'ko')
    plt.xlabel('Q')
    plt.ylabel('loss')
plt.show()

# %%
acf.shape, t.shape, y.shape
# Out:
# ((35001,), (35001,), (1, 35001))

# %%
for xx in np.linspace(250, 350, 20):
    plt.plot(xx, objective_function(xx), 'ko')
    plt.xlabel('Q')
    plt.ylabel('loss')
plt.show()

# %%
# loss = np.sum((np.mean(ACF, axis=0)[t<=600] - np.array(kernel(dx, dx[:1])).flatten())**2)

# if 0:
#     from scipy.optimize import minimize
#     # bounds = [(0,1), (200, 500)]
#     res = minimize(
#         loss,
#         x0=([400]),
#         # args=(amp, Q,),
#         # bounds=bounds,
#     )

# %%
# y= y[0,:]

theta_init = {
    # "log_diag": np.log(0.5),
    "log_Q": np.log(1000),
    # "log_A": np.log(amp0),
    # "log_W": np.log(300),
    # "log_nu_max": np.log(3080),
    # "log_delta_nu": np.log(135),
    # "epsilon": np.float64(0.0)
}

obj = jax.jit(jax.value_and_grad(neg_log_likelihood))

print(f"Initial negative log likelihood: {obj(theta_init, t, y)[0]}")
print(
    f"Gradient of the negative log likelihood, wrt the parameters:\n{obj(theta_init, t, y)[1]}"
)

w_init = jnp.zeros(len(theta_init))
lower_bounds = jnp.ones_like(w_init)* (-1)
upper_bounds = jnp.ones_like(w_init) * jnp.inf
bounds = (lower_bounds, upper_bounds)

import jaxopt
solver = jaxopt.ScipyBoundedMinimize(fun=neg_log_likelihood)
soln = solver.run(theta_init, bounds=bounds, X=t, y= y)
print(f"Final negative log likelihood: {soln.state.fun_val}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [27], line 15
#       3 theta_init = {
#       4     # "log_diag": np.log(0.5),
#       5     "log_Q": np.log(1000),
#    (...)
#      10     # "epsilon": np.float64(0.0)
#      11 }
#      13 obj = jax.jit(jax.value_and_grad(neg_log_likelihood))
# ---> 15 print(f"Initial negative log likelihood: {obj(theta_init, t, y)[0]}")
#      16 print(
#      17     f"Gradient of the negative log likelihood, wrt the parameters:\n{obj(theta_init, t, y)[1]}"
#      18 )
#      20 w_init = jnp.zeros(len(theta_init))
#
#     [... skipping hidden 19 frame]
#
# Cell In [12], line 17, in neg_log_likelihood(theta, X, y)
#      16 def neg_log_likelihood(theta, X, y):
# ---> 17     gp, _ = build_gp(theta, X)
#      18     return -gp.log_probability(y)
#
# Cell In [12], line 6, in build_gp(theta, X)
#       1 def build_gp(theta, X):
#       2
#       3     # We want most of our parameters to be positive so we take the `exp` here
#       4     # Note that we're using `jnp` instead of `np`
#       5     Q = jnp.exp(theta["log_Q"])
# ----> 6     nu_max = jnp.exp(theta["log_nu_max"])
#       8     kernel = 0
#       9     for i in range(N):
#
# KeyError: 'log_nu_max'

# %%
soln.params

# %%
for key, value in soln.params.items():
    print(key[4:], np.exp(value))
